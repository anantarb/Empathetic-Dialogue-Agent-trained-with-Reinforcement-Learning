# %%
# %tensorflow_version 1.13.1

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# %cd /content/drive/My Drive/nlp-2021-vda/annotate_data
# !pwd

# %% [markdown]
# If you want to continue annotation from where we left off, download the data from google cloud.

# %%
import os
if not os.path.isdir('./datasets'):
    os.mkdir('./datasets')
if not os.path.isdir('./datasets/distributed_data'):
    # !gsutil -m cp -r gs://nlp-lab/annotate_data/datasets/distributed_data ./datasets/
if not os.path.isdir('./datasets/annotated'):
    # !gsutil -m cp -r gs://nlp-lab/annotate_data/datasets/annotated ./datasets/

# %%
from data.annotate import annotate

# %%
# inputfile - distributed data path
inputfile = 'datasets/distributed_data/distributed_data.json'
annotate(inputfile)
