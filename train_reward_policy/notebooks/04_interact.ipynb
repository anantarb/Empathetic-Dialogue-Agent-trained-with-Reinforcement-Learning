# %%
# %tensorflow_version 1.13.1

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# %cd /content/drive/My Drive/nlp-2021-vda/train_reward_policy/
# !pwd

# %% [markdown]
# If you want to interact with our RL fine-tuned model, download model from google cloud storage.

# %%
import os

if not os.path.isdir('./model_saves'):
    # !gsutil -m cp -r gs://nlp-lab/train_policy_reward/model_saves ./

# %%
# !pip install ftfy

# %%
# run_name - directory where model checkpoints are located inside checkpoints
# checkpoint_dir - name of checkpoint dir
# seed - specify seed if you want to reproduce results
# length - maximum length of responses
# history_len - How many previous dialogues should be used in the context
# temperature - temperature value while interacting

import interact
interact.run(run_name='policy-2',
    checkpoint_dir='model_saves',
    seed=None,
    length=100,
    history_len=4,
    temperature=0.7)
